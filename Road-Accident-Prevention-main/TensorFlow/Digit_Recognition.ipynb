# %%
import os
import numpy as np
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# !pip install tensorflowjs

# %matplotlib inline

# %%
# load dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
# reshape the data
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')

# %%
# label encoding
from keras.utils.np_utils import to_categorical
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# %%
# normalization
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
# splitting the data
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

# %%
# build model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.models import Sequential

num_classes = 10

model = Sequential()
model.add(Conv2D(8, (5, 5), strides=1, activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Conv2D(16, (5, 5), strides=1, activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# data augmentation
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
  shear_range=0.2,
  zoom_range=0.2,
  rotation_range=15,
)

# %%
batch_size = 200
epochs = 10

history = model.fit_generator(
  train_datagen.flow(X_train, y_train, batch_size=batch_size),
  steps_per_epoch=len(X_train) // batch_size,
  validation_data=(X_val, y_val),
  validation_steps=len(X_val) // batch_size,
  epochs=epochs
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   if __name__ == '__main__':
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f04e5d13f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f04e5d13f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 270/270 [==============================] - ETA: 0s - loss: 0.6822 - accuracy: 0.7980WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f04e30499e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f04e30499e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 270/270 [==============================] - 37s 131ms/step - loss: 0.6822 - accuracy: 0.7980 - val_loss: 0.1918 - val_accuracy: 0.9440
# Epoch 2/10
# 270/270 [==============================] - 27s 101ms/step - loss: 0.2399 - accuracy: 0.9285 - val_loss: 0.1213 - val_accuracy: 0.9658
# Epoch 3/10
# 270/270 [==============================] - 27s 100ms/step - loss: 0.1783 - accuracy: 0.9467 - val_loss: 0.1018 - val_accuracy: 0.9707
# Epoch 4/10
# 270/270 [==============================] - 27s 101ms/step - loss: 0.1507 - accuracy: 0.9538 - val_loss: 0.0903 - val_accuracy: 0.9743
# Epoch 5/10
# 270/270 [==============================] - 27s 99ms/step - loss: 0.1316 - accuracy: 0.9599 - val_loss: 0.0771 - val_accuracy: 0.9783
# Epoch 6/10
# 270/270 [==============================] - 27s 98ms/step - loss: 0.1210 - accuracy: 0.9631 - val_loss: 0.0736 - val_accuracy: 0.9790
# Epoch 7/10
# 270/270 [==============================] - 26s 98ms/step - loss: 0.1134 - accuracy: 0.9651 - val_loss: 0.0680 - val_accuracy: 0.9798
# Epoch 8/10
# 270/270 [==============================] - 26s 98ms/step - loss: 0.1030 - accuracy: 0.9684 - val_loss: 0.0617 - val_accuracy: 0.9812
# Epoch 9/10
# 270/270 [==============================] - 27s 100ms/step - loss: 0.0947 - accuracy: 0.9712 - val_loss: 0.0565 - val_accuracy: 0.9832
# Epoch 10/10
# 270/270 [==============================] - 27s 101ms/step - loss: 0.0895 - accuracy: 0.9726 - val_loss: 0.0539 - val_accuracy: 0.9840

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.plot(history.history["accuracy"], label="train_acc")
plt.plot(history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="best")

# %%
Y_predict = model.predict(X_test, batch_size=batch_size)
pred_idx = np.argmax(Y_predict, axis=1)

from sklearn.metrics import classification_report

# show a nicely formatted classification report
print(classification_report(y_test.argmax(axis=1), pred_idx, target_names= [str(c) for c in range(10)]))
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f04e9be8320> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f04e9be8320> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.99      0.98      0.98      1032
#            3       0.98      0.99      0.99      1010
#            4       0.99      0.98      0.98       982
#            5       0.99      0.98      0.99       892
#            6       0.99      0.99      0.99       958
#            7       0.97      0.99      0.98      1028
#            8       0.98      0.97      0.98       974
#            9       0.98      0.98      0.98      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("Test accuracy: {:.4f}".format(scores[1]))
# Out:
# Test accuracy: 0.9848

# %%
# plot the images in a grid
size = 30
rows = 3
f = plt.figure(figsize=(size // rows, rows + 1))
plt.suptitle("Test dataset recognition", fontsize=10)
for i in range(size):
    sp = f.add_subplot(rows, -(-size // rows), i + 1)
    sp.axis('Off')
    plt.imshow(X_test[i][:,:,0], cmap='gray_r')
    sp.set_title(Y_predict[i].argmax(), fontsize=16)

plt.savefig('test_dataset_recognition.png')

# %%
model.save('keras.h5')

# %%
# %mkdir model

# !tensorflowjs_converter --input_format keras keras.h5 model/

# %%
# Download model
from google.colab import files
# !zip -r model.zip model
files.download('model.zip')
# Out:
#   adding: model/ (stored 0%)
#   adding: model/model.json (deflated 76%)
#   adding: model/group1-shard1of1.bin (deflated 7%)
